# %%
import pandas as pd
import os

# %%
# calendar_dec18.csv
# cleansed_listings_dec18.csv
# listings_dec18.csv
# listings_summary_dec18.csv
# reviews_dec18.csv
# reviews_summary_dec18.csv

# %%
dir = 'D:\Downloads\melbourne-airbnb-open-data\\'
onlyfiles = next(os.walk(dir))[2];
onlyfiles
# Out:
# ['calendar_dec18.csv',
#  'cleansed_listings_dec18.csv',
#  'listings_dec18.csv',
#  'listings_summary_dec18.csv',
#  'neighbourhoods.csv',
#  'reviews_dec18.csv',
#  'reviews_summary_dec18.csv']

# %%
data = [pd.read_csv(dir+file) for file in onlyfiles]

# %%
data[0].head()
# Out:
#    listing_id        date available price
# 0      136510  2019-10-15         f   NaN
# 1      136510  2019-10-14         f   NaN
# 2      136510  2019-10-13         f   NaN
# 3      136510  2019-10-12         f   NaN
# 4      136510  2019-10-11         f   NaN

# %%
data[1].head()
# Out:
#       id                         listing_url     scrape_id last_scraped  \
# 0   9835   https://www.airbnb.com/rooms/9835  2.018120e+13    12/7/2018
# 1  10803  https://www.airbnb.com/rooms/10803  2.018120e+13    12/7/2018
# 2  12936  https://www.airbnb.com/rooms/12936  2.018120e+13    12/7/2018
# 3  15246  https://www.airbnb.com/rooms/15246  2.018120e+13    12/7/2018
# 4  16760  https://www.airbnb.com/rooms/16760  2.018120e+13    12/7/2018
#
#                                                name  \
# 0                            Beautiful Room & House
# 1          Room in Cool Deco Apartment in Brunswick
# 2  St Kilda 1BR APT+BEACHSIDE+VIEWS+PARKING+WIFI+AC
# 3                  Large private room-close to city
# 4                  Melbourne BnB near City & Sports
#
#                                              summary  \
# 0                                                NaN
# 1  A large air conditioned room with queen spring...
# ...

# %%
data[2].head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   9835   https://www.airbnb.com/rooms/9835  20181207034809   2018-12-07
# 1  10803  https://www.airbnb.com/rooms/10803  20181207034809   2018-12-07
# 2  12936  https://www.airbnb.com/rooms/12936  20181207034809   2018-12-07
# 3  15246  https://www.airbnb.com/rooms/15246  20181207034809   2018-12-07
# 4  16760  https://www.airbnb.com/rooms/16760  20181207034809   2018-12-07
#
#                                                name  \
# 0                            Beautiful Room & House
# 1          Room in Cool Deco Apartment in Brunswick
# 2  St Kilda 1BR APT+BEACHSIDE+VIEWS+PARKING+WIFI+AC
# 3                  Large private room-close to city
# 4                  Melbourne BnB near City & Sports
#
#                                              summary  \
# 0                                                NaN
# 1  A large air conditioned room with queen spring...
# ...

# %%
data[3].head()
# Out:
#       id                                              name  host_id  \
# 0   9835                            Beautiful Room & House    33057
# 1  10803          Room in Cool Deco Apartment in Brunswick    38901
# 2  12936  St Kilda 1BR APT+BEACHSIDE+VIEWS+PARKING+WIFI+AC    50121
# 3  15246                  Large private room-close to city    59786
# 4  16760                  Melbourne BnB near City & Sports    65090
#
#        host_name  neighbourhood_group neighbourhood   latitude   longitude  \
# 0          Manju                  NaN    Manningham -37.772684  145.092133
# 1        Lindsay                  NaN      Moreland -37.766505  144.980736
# 2  Frank & Vince                  NaN  Port Phillip -37.859755  144.977369
# 3          Eleni                  NaN       Darebin -37.758971  144.989228
# 4          Colin                  NaN  Port Phillip -37.864530  144.992238
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data[4].head()
# Out:
#    neighbourhood_group neighbourhood
# 0                  NaN       Banyule
# 1                  NaN       Bayside
# 2                  NaN    Boroondara
# 3                  NaN      Brimbank
# 4                  NaN      Cardinia

# %%
data[5].head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        9835    279854  2011-05-24       560832        Miriam
# 1        9835   3640746  2013-02-26      5143343      Michelle
# 2        9835  23731188  2014-12-08      2478713         Karyn
# 3        9835  46588875  2015-09-12     26184717      Rosalind
# 4       10803   3333588  2013-01-12      4421189      Johannes
#
#                                             comments
# 0             Very hospitable, much appreciated.\r\n
# 1  A beautiful house in a lovely quiet neighbourh...
# 2  This was my first time using airbnb and it was...
# 3  I was visiting Melbourne to spend time with my...
# 4  It was very convenient  to stay in Lindsay's a...

# %%
data[6].head()
# Out:
#    listing_id        date
# 0        9835  2011-05-24
# 1        9835  2013-02-26
# 2        9835  2014-12-08
# 3        9835  2015-09-12
# 4       10803  2013-01-12
